# %%
import matplotlib.pyplot as plt
import numpy as np

# (CURRENT--tanh 1000)
# rnn: Shakespeare and Sherlock 
# relu: size 10, 100, 1000
# tanh: size 10, 100, 1000
    
# GRU: Shakespeare and Sherlock
# size 10, 100, 1000
    
# LSTM: Shakespeare and Sherlock
# size 10, 100, 1000  

# if have time
# optimizers: SGD, RMSProp
# hidden layers
# bidirectional

# %%
## rnn(relu) hidden size 100 Shakespeare 10:19AM
plt.xlabel('iters')
plt.ylabel('loss')
plt.plot(np.load("original_RNN.npy"))
plt.show()

# %%
## rnn(relu) hidden size 10 Shakespeare 9:23AM-10:17AM
plt.xlabel('iters')
plt.ylabel('loss')
plt.plot(np.load("original_RNN_10.npy"))
plt.show()

# %%
## rnn(relu) hidden size 1000 Shakespeare
plt.xlabel('iters')
plt.ylabel('loss')
plt.plot(np.load("original_RNN_1000.npy"))
plt.show()

# %%
type(plt)
# Out:
# module

# %%
## rnn(relu VS tanh) hidden size 10 Shakespeare 
plt.xlabel('iters')
plt.ylabel('loss')
# plt.title('relu vs tanh')
plt.plot(np.load("original_RNN_10.npy"), label = 'Relu')
plt.plot(np.load("original_RNN_10_tanh.npy"), label = 'tanh')
plt.legend(loc='best')
plt.show()

# %%
## rnn(relu VS tanh) hidden size 10 Shakespeare 
plt.xlabel('iters')
plt.ylabel('loss')
# plt.title('relu vs tanh')
plt.plot(np.load("original_RNN_1000.npy"), label = 'Relu')
plt.plot(np.load("tanh_RNN_1000.npy"), label = 'tanh')
plt.legend(loc='best')
plt.show()

# %%
## rnn(relu VS tanh) hidden size 10 Shakespeare 
plt.xlabel('iters')
plt.ylabel('loss')
# plt.title('relu vs tanh')
plt.plot(np.load("original_RNN.npy"), label = 'Relu')
plt.plot(np.load("original_RNN_tanh.npy"), label = 'tanh')
plt.legend(loc='best')
plt.show()

# %%
## rnn(tanh) hidden size 10 Shakespeare
plt.xlabel('iters')
plt.ylabel('loss')
plt.plot(np.load("original_RNN_10_tanh.npy"))

plt.show()

# %%
## rnn(tanh) hidden size 100 Shakespeare
plt.xlabel('iters')
plt.ylabel('loss')
plt.plot(np.load("original_RNN_tanh.npy"))
plt.show()

# %%
## rnn(tanh) hidden size 1000 Shakespeare
plt.xlabel('iters')
plt.ylabel('loss')
plt.plot(np.load("tanh_RNN_1000.npy"))
plt.show()

# %%
plt.xlabel('iters')
plt.ylabel('loss')
plt.title("RNN")
plt.plot(np.load("original_RNN_10.npy"), label='Relu-10')
plt.plot(np.load("original_RNN.npy"), label='Relu-100')
plt.plot(np.load("original_RNN_1000.npy"), label='Relu-1000')
plt.plot(np.load("original_RNN_10_tanh.npy"), label='tanh-10')
plt.plot(np.load("original_RNN_tanh.npy"), label='tanh-100')
plt.plot(np.load("tanh_RNN_1000.npy"), label='tanh-1000')
plt.legend(loc='best')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-422e8a9bd8cc> in <module>
#       3 plt.title("RNN")
#       4 plt.plot(np.load("original_RNN_10.npy"), label='Relu-10')
# ----> 5 plt.plot(np.load("original_RNN.npy"), label='Relu-100')
#       6 plt.plot(np.load("original_RNN_1000.npy"), label='Relu-1000')
#       7 plt.plot(np.load("original_RNN_10_tanh.npy"), label='tanh-10')
#
# /opt/conda/lib/python3.7/site-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     449             # Try a pickle
#     450             if not allow_pickle:
# --> 451                 raise ValueError("Cannot load file containing pickled data "
#     452                                  "when allow_pickle=False")
#     453             try:
#
# ValueError: Cannot load file containing pickled data when allow_pickle=False

# %%
plt.xlabel('iters')
plt.ylabel('loss')
# plt.title("RNN")
# plt.plot(np.load("original_RNN_10.npy"), label='Relu-10')
# plt.plot(np.load("original_RNN.npy"), label='Relu-100')
# plt.plot(np.load("original_RNN_1000.npy"), label='Relu-1000')
plt.plot(np.load("original_RNN_10_tanh.npy"), label='tanh-10')
plt.plot(np.load("original_RNN_tanh.npy"), label='tanh-100')
plt.plot(np.load("tanh_RNN_1000.npy"), label='tanh-1000')
plt.legend(loc='best')
plt.show()

# %%
plt.xlabel('iters')
plt.ylabel('loss')
# plt.title("RNN")
plt.plot(np.load("original_RNN_10.npy"), label='Relu-10')
plt.plot(np.load("original_RNN.npy"), label='Relu-100')
plt.plot(np.load("original_RNN_1000.npy"), label='Relu-1000')
# plt.plot(np.load("original_RNN_10_tanh.npy"), label='tanh-10')
# plt.plot(np.load("original_RNN_tanh.npy"), label='tanh-100')
# plt.plot(np.load("tanh_RNN_1000.npy"), label='tanh-1000')
plt.legend(loc='best')
plt.show()

# %%
## gru hidden size 100 Shakespeare
plt.xlabel('iters')
plt.ylabel('loss')
plt.plot(np.load("GRU_100.npy"))
plt.show()

# %%
## gru hidden size 10 Shakespeare
plt.xlabel('iters')
plt.ylabel('loss')
plt.plot(np.load("GRU_10.npy"))
plt.show()

# %%
## gru hidden size 100 Shakespeare
plt.xlabel('iters')
plt.ylabel('loss')
plt.plot(np.load("rnn_LSTM.npy"))
plt.show()

# %%
## gru hidden size 100 Shakespeare
plt.xlabel('iters')
plt.ylabel('loss')
plt.plot(np.load("rnn_LSTM.npy"), label = 'LSTM')
plt.plot(np.load("GRU_100.npy"), label = 'GRU')
plt.plot(np.load("original_RNN_tanh.npy"), label = 'Vanilla RNN')
plt.legend(loc='best')
plt.show()
